# %%
################################################################################################################################################################################
#   
#   Visualisation Template for the optimization process of algorithms
#   Author:  Tjark Ziehm
#   
#   Goal:
#         1 Dimensional: Visualization for the exploration of f(x) = x^2
#         2 Dimensional: Visualization for the exploration of f(x, y) = x^2 + y^2
#                        using contour plot
#                        @wiki https://en.wikipedia.org/wiki/Contour_line
#         3 Dimensional: Visualization
#   
#   @Version 0.01 Dezember 2021
#   @Github: https://github.com/ohioh/IntroductionQuantumComputing/
#   @Gitbook: 
#
################################################################################################################################################################################

# %%
# line plot of domain for a 1d function with optima and algorithm sample
from numpy import arange,meshgrid
from numpy.random import seed, rand

import matplotlib
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D, art3d
from matplotlib import cm
from matplotlib.patches import Circle

# %matplotlib inline

# %%
# exampe for a 1 dimensional object function

#object function
def objective(x):
    return x**2

#evaluate inputs to the objective function
x=4.0
result = objective(x)
print('f(%.3f) = %.3f' % (x, result))
# Out:
# f(4.000) = 16.000

# %% [markdown]
# The first thing we might want to do with a new function is define an input range of interest and sample the domain of interest using a uniform grid.
#
# This sample will provide the basis for generating a plot later.
#
# In this case, we will define a domain of interest around the optima of x=0.0 from x=-5.0 to x=5.0 and sample a grid of values in this range with 0.1 increments, such as -5.0, -4.9, -4.8, etc.

# %%
# define range for input 
r_min, r_max = -5.0, 5.0

# sample input range uniformly at 0.1 increments as the result for the x-axis in an array
inputs = arange(r_min, r_max, 0.1)

# summarize some of the input domain
print(inputs[:5])
# Out:
# [-5.  -4.9 -4.8 -4.7 -4.6]

# %%
# compute targets result for the y-axis in an array
results = objective(inputs)

# summarize some of the results
print(results[:5])
# Out:
# [25.   24.01 23.04 22.09 21.16]

# %%
# create a mapping of some inputs to some results
for i in range(5):
	print('f(%.3f) = %.3f' % (inputs[i], results[i]))
# Out:
# f(-5.000) = 25.000
# f(-4.900) = 24.010
# f(-4.800) = 23.040
# f(-4.700) = 22.090
# f(-4.600) = 21.160

# %% [markdown]
# LinePlot

# %%
...
# create a line plot of input vs result
plt.plot(inputs, results)
# show the plot
plt.show()

# %% [markdown]
# Scatter Plot of Test Function

# %%
# create a scatter plot of input vs result
plt.scatter(inputs, results)
# show the plot
plt.show()

# %% [markdown]
# Line Plot with Marked Optima

# %%
# define the known function optima
optima_x = 0.0
optima_y = objective(optima_x)

# %%
# create a line plot of input vs result
pyplot.plot(inputs, results)

# %%
# draw the function optima as a red square
pyplot.plot([optima_x], [optima_y], 's', color='r')

# %%
# define range for input
r_min, r_max = -5.0, 5.0

# sample input range uniformly at 0.1 increments
inputs = arange(r_min, r_max, 0.1)

# compute targets
results = objective(inputs)

# create a line plot of input vs result
pyplot.plot(inputs, results)

# define the known function optima
optima_x = 0.0
optima_y = objective(optima_x)

# draw a vertical line at the optimal input
pyplot.axvline(x=optima_x, ls='--', color='red')

# draw the function optima as a red square
pyplot.plot([optima_x], [optima_y], 's', color='r')

# show the plot

# %% [markdown]
# Line Plot with Samples

# %%
# simulate a sample made by an optimization algorithm
seed(1)
sample = r_min + rand(10) * (r_max - r_min)

# evaluate the sample
sample_eval = objective(sample)

# %%
# create a line plot of input vs result
pyplot.plot(inputs, results)

# define the known function optima
optima_x = 0.0

# draw a vertical line at the optimal input
pyplot.axvline(x=optima_x, ls='--', color='red')

#plot the sample as black circles
pyplot.plot(sample, sample_eval, 'o', color='black')

# show the plot
pyplot.show()

# %% [markdown]
# Visualize 2D Function Optimization

# %%
# objective function
def objective2D(x, y):
	return x**2.0 + y**2.0
 
# evaluate inputs to the objective function
x = 4.0
y = 4.0

result = objective2D(x, y)

print('f(%.3f, %.3f) = %.3f' % (x, y, result))
# Out:
# f(4.000, 4.000) = 32.000

# %%
# define range for input
r_min, r_max = -5.0, 5.0

# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)

# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)

# summarize some of the input domain
print(x[:5, :5])
# Out:
# [[-5.  -4.9 -4.8 -4.7 -4.6]
#  [-5.  -4.9 -4.8 -4.7 -4.6]
#  [-5.  -4.9 -4.8 -4.7 -4.6]
#  [-5.  -4.9 -4.8 -4.7 -4.6]
#  [-5.  -4.9 -4.8 -4.7 -4.6]]

# %%
# compute targets
results = objective2D(x, y)

# summarize some of the results
print(results[:5, :5])
# Out:
# [[50.   49.01 48.04 47.09 46.16]
#  [49.01 48.02 47.05 46.1  45.17]
#  [48.04 47.05 46.08 45.13 44.2 ]
#  [47.09 46.1  45.13 44.18 43.25]
#  [46.16 45.17 44.2  43.25 42.32]]

# %%
# create a mapping of some inputs to some results
for i in range(100):
	print('f(%.3f, %.3f) = %.3f' % (x[i,0], y[i,0], results[i,0]))
# Out:
# f(-5.000, -5.000) = 50.000
# f(-5.000, -4.900) = 49.010
# f(-5.000, -4.800) = 48.040
# f(-5.000, -4.700) = 47.090
# f(-5.000, -4.600) = 46.160
# f(-5.000, -4.500) = 45.250
# f(-5.000, -4.400) = 44.360
# f(-5.000, -4.300) = 43.490
# f(-5.000, -4.200) = 42.640
# f(-5.000, -4.100) = 41.810
# f(-5.000, -4.000) = 41.000
# f(-5.000, -3.900) = 40.210
# f(-5.000, -3.800) = 39.440
# f(-5.000, -3.700) = 38.690
# f(-5.000, -3.600) = 37.960
# f(-5.000, -3.500) = 37.250
# f(-5.000, -3.400) = 36.560
# f(-5.000, -3.300) = 35.890
# f(-5.000, -3.200) = 35.240
# f(-5.000, -3.100) = 34.610
# f(-5.000, -3.000) = 34.000
# f(-5.000, -2.900) = 33.410
# f(-5.000, -2.800) = 32.840
# f(-5.000, -2.700) = 32.290
# f(-5.000, -2.600) = 31.760
# f(-5.000, -2.500) = 31.250
# f(-5.000, -2.400) = 30.760
# f(-5.000, -2.300) = 30.290
# f(-5.000, -2.200) = 29.840
# f(-5.000, -2.100) = 29.410
# f(-5.000, -2.000) = 29.000
# f(-5.000, -1.900) = 28.610
# f(-5.000, -1.800) = 28.240
# f(-5.000, -1.700) = 27.890
# f(-5.000, -1.600) = 27.560
# f(-5.000, -1.500) = 27.250
# f(-5.000, -1.400) = 26.960
# f(-5.000, -1.300) = 26.690
# f(-5.000, -1.200) = 26.440
# f(-5.000, -1.100) = 26.210
# f(-5.000, -1.000) = 26.000
# f(-5.000, -0.900) = 25.810
# f(-5.000, -0.800) = 25.640
# f(-5.000, -0.700) = 25.490
# f(-5.000, -0.600) = 25.360
# f(-5.000, -0.500) = 25.250
# f(-5.000, -0.400) = 25.160
# f(-5.000, -0.300) = 25.090
# f(-5.000, -0.200) = 25.040
# f(-5.000, -0.100) = 25.010
# f(-5.000, -0.000) = 25.000
# f(-5.000, 0.100) = 25.010
# f(-5.000, 0.200) = 25.040
# f(-5.000, 0.300) = 25.090
# f(-5.000, 0.400) = 25.160
# f(-5.000, 0.500) = 25.250
# f(-5.000, 0.600) = 25.360
# f(-5.000, 0.700) = 25.490
# f(-5.000, 0.800) = 25.640
# f(-5.000, 0.900) = 25.810
# f(-5.000, 1.000) = 26.000
# f(-5.000, 1.100) = 26.210
# f(-5.000, 1.200) = 26.440
# f(-5.000, 1.300) = 26.690
# f(-5.000, 1.400) = 26.960
# f(-5.000, 1.500) = 27.250
# f(-5.000, 1.600) = 27.560
# f(-5.000, 1.700) = 27.890
# f(-5.000, 1.800) = 28.240
# f(-5.000, 1.900) = 28.610
# f(-5.000, 2.000) = 29.000
# f(-5.000, 2.100) = 29.410
# f(-5.000, 2.200) = 29.840
# f(-5.000, 2.300) = 30.290
# f(-5.000, 2.400) = 30.760
# f(-5.000, 2.500) = 31.250
# f(-5.000, 2.600) = 31.760
# f(-5.000, 2.700) = 32.290
# f(-5.000, 2.800) = 32.840
# f(-5.000, 2.900) = 33.410
# f(-5.000, 3.000) = 34.000
# f(-5.000, 3.100) = 34.610
# f(-5.000, 3.200) = 35.240
# f(-5.000, 3.300) = 35.890
# f(-5.000, 3.400) = 36.560
# f(-5.000, 3.500) = 37.250
# f(-5.000, 3.600) = 37.960
# f(-5.000, 3.700) = 38.690
# f(-5.000, 3.800) = 39.440
# f(-5.000, 3.900) = 40.210
# f(-5.000, 4.000) = 41.000
# f(-5.000, 4.100) = 41.810
# f(-5.000, 4.200) = 42.640
# f(-5.000, 4.300) = 43.490
# f(-5.000, 4.400) = 44.360
# f(-5.000, 4.500) = 45.250
# f(-5.000, 4.600) = 46.160
# f(-5.000, 4.700) = 47.090
# f(-5.000, 4.800) = 48.040
# f(-5.000, 4.900) = 49.010

# %%
for i in range(100):
	print('f(%.3f, %.3f) = %.3f' % (x[0,i], y[0,i], results[0,i]))
# Out:
# f(-5.000, -5.000) = 50.000
# f(-4.900, -5.000) = 49.010
# f(-4.800, -5.000) = 48.040
# f(-4.700, -5.000) = 47.090
# f(-4.600, -5.000) = 46.160
# f(-4.500, -5.000) = 45.250
# f(-4.400, -5.000) = 44.360
# f(-4.300, -5.000) = 43.490
# f(-4.200, -5.000) = 42.640
# f(-4.100, -5.000) = 41.810
# f(-4.000, -5.000) = 41.000
# f(-3.900, -5.000) = 40.210
# f(-3.800, -5.000) = 39.440
# f(-3.700, -5.000) = 38.690
# f(-3.600, -5.000) = 37.960
# f(-3.500, -5.000) = 37.250
# f(-3.400, -5.000) = 36.560
# f(-3.300, -5.000) = 35.890
# f(-3.200, -5.000) = 35.240
# f(-3.100, -5.000) = 34.610
# f(-3.000, -5.000) = 34.000
# f(-2.900, -5.000) = 33.410
# f(-2.800, -5.000) = 32.840
# f(-2.700, -5.000) = 32.290
# f(-2.600, -5.000) = 31.760
# f(-2.500, -5.000) = 31.250
# f(-2.400, -5.000) = 30.760
# f(-2.300, -5.000) = 30.290
# f(-2.200, -5.000) = 29.840
# f(-2.100, -5.000) = 29.410
# f(-2.000, -5.000) = 29.000
# f(-1.900, -5.000) = 28.610
# f(-1.800, -5.000) = 28.240
# f(-1.700, -5.000) = 27.890
# f(-1.600, -5.000) = 27.560
# f(-1.500, -5.000) = 27.250
# f(-1.400, -5.000) = 26.960
# f(-1.300, -5.000) = 26.690
# f(-1.200, -5.000) = 26.440
# f(-1.100, -5.000) = 26.210
# f(-1.000, -5.000) = 26.000
# f(-0.900, -5.000) = 25.810
# f(-0.800, -5.000) = 25.640
# f(-0.700, -5.000) = 25.490
# f(-0.600, -5.000) = 25.360
# f(-0.500, -5.000) = 25.250
# f(-0.400, -5.000) = 25.160
# f(-0.300, -5.000) = 25.090
# f(-0.200, -5.000) = 25.040
# f(-0.100, -5.000) = 25.010
# f(-0.000, -5.000) = 25.000
# f(0.100, -5.000) = 25.010
# f(0.200, -5.000) = 25.040
# f(0.300, -5.000) = 25.090
# f(0.400, -5.000) = 25.160
# f(0.500, -5.000) = 25.250
# f(0.600, -5.000) = 25.360
# f(0.700, -5.000) = 25.490
# f(0.800, -5.000) = 25.640
# f(0.900, -5.000) = 25.810
# f(1.000, -5.000) = 26.000
# f(1.100, -5.000) = 26.210
# f(1.200, -5.000) = 26.440
# f(1.300, -5.000) = 26.690
# f(1.400, -5.000) = 26.960
# f(1.500, -5.000) = 27.250
# f(1.600, -5.000) = 27.560
# f(1.700, -5.000) = 27.890
# f(1.800, -5.000) = 28.240
# f(1.900, -5.000) = 28.610
# f(2.000, -5.000) = 29.000
# f(2.100, -5.000) = 29.410
# f(2.200, -5.000) = 29.840
# f(2.300, -5.000) = 30.290
# f(2.400, -5.000) = 30.760
# f(2.500, -5.000) = 31.250
# f(2.600, -5.000) = 31.760
# f(2.700, -5.000) = 32.290
# f(2.800, -5.000) = 32.840
# f(2.900, -5.000) = 33.410
# f(3.000, -5.000) = 34.000
# f(3.100, -5.000) = 34.610
# f(3.200, -5.000) = 35.240
# f(3.300, -5.000) = 35.890
# f(3.400, -5.000) = 36.560
# f(3.500, -5.000) = 37.250
# f(3.600, -5.000) = 37.960
# f(3.700, -5.000) = 38.690
# f(3.800, -5.000) = 39.440
# f(3.900, -5.000) = 40.210
# f(4.000, -5.000) = 41.000
# f(4.100, -5.000) = 41.810
# f(4.200, -5.000) = 42.640
# f(4.300, -5.000) = 43.490
# f(4.400, -5.000) = 44.360
# f(4.500, -5.000) = 45.250
# f(4.600, -5.000) = 46.160
# f(4.700, -5.000) = 47.090
# f(4.800, -5.000) = 48.040
# f(4.900, -5.000) = 49.010

# %% [markdown]
# Contour Plot of Test Function

# %%
# create a contour plot with 50 levels and jet color scheme
pyplot.contour(x, y, results, 50, alpha=1.0, cmap='jet')
# show the plot
pyplot.show()

# %% [markdown]
# Filled Contour Plot of Test Function

# %%
# create a filled contour plot with 50 levels and jet color scheme
pyplot.contourf(x, y, results, levels=50, cmap='jet')

# define the known function optima
optima_x = [0.0, 0.0]

# draw the function optima as a white star
pyplot.plot([optima_x[0]], [optima_x[1]], '*', color='white')

# %% [markdown]
# Filled Contour Plot of Test Function with Samples

# %%
# simulate a sample made by an optimization algorithm
seed(1)

sample_x = r_min + rand(10) * (r_max - r_min)
sample_y = r_min + rand(10) * (r_max - r_min)

# %%
# create a filled contour plot with 50 levels and jet color scheme
pyplot.contourf(x, y, results, levels=50, cmap='jet')

# define the known function optima
optima_x = [0.0, 0.0]

# draw the function optima as a white star
pyplot.plot([optima_x[0]], [optima_x[1]], '*', color='white')

# plot the sample as black circles
pyplot.plot(sample_x, sample_y, 'o', color='black')

# show the plot
pyplot.show()

# %% [markdown]
# Surface Plot of Test Function

# %%
# create a surface plot with the jet color scheme
figure = pyplot.figure(figsize=(6,6),dpi=100)
ax = figure.add_subplot(111, projection='3d')
#ax.scatter(xs = sample_x, ys = sample_y, zs = results, label=l)

axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')

axis.set_xlabel("x axis")
axis.set_ylabel("y axis")
#axis.scatter(xs = sample_x, ys = sample_y, zs = results, label=l)

p = Circle((-2, 3), 0.1, ec='k', fc="none")
axis.add_patch(p)
art3d.pathpatch_2d_to_3d(p, z=20, zdir="z")
# Out:
# /tmp/ipykernel_14361/3157715648.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   axis = figure.gca(projection='3d')
